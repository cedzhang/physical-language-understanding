# %% [markdown]
# # codex_prompting.ipynb
#
# Author: Gabriel Grand (grandg@mit.edu) | Date: 01-30-23
#
# Code for prompting codex to generate conditioning statements for physical language tasks.

# %%
import openai
import os
import pandas as pd
import re
import datetime
import pickle
import json

from tqdm import tqdm

# %%
# Configure OpenAI API

openai.api_key = os.environ["OPENAI_API_KEY"]

ENGINE = "code-davinci-002"
MAX_TOKENS = 512
N_SAMPLES = 1
TEMPERATURE = 0.0
STOP = "/**"

# %%
RANDOM_SEED = 123

DIR_DATA = "data"
DIR_EXPERIMENTS = "../experiments"
DIR_CODEX = "codex"
DIR_COMPLETIONS = "completions"
DIR_PROMPTS = "prompts"

FILE_GENERATIVE_MODEL = os.path.join(DIR_DATA, "generative_model.js")
# FILE_STIMULI = os.path.join(DIR_DATA, "phys_lang_examples.csv")
FILE_STIMULI = os.path.join(DIR_DATA, "stimuli_v1.csv")

# %%
with open(FILE_GENERATIVE_MODEL, "r") as f:
    generative_model_text = f.read()

# %%
print(f"{generative_model_text}")
# Out:
# /**
#  * WebPPL generative model of a blockworld.
#  */
# var makeBlockWorld = function () {
#
#     //// Distributions and parameters ////
#
#     var truncGeom = function (p, m, n) {
#         if (m > n) {
#             return uniformDraw(_.range(1, n + 1));
#         } else {
#             return flip(p) ? truncGeom(p, m + 1, n) : m;
#         }
#     }
#
#     var dim = 10;
#     var tableSize = 100;
#     var worldWidth = 600;
#     var worldHeight = 500;
#     var color = function () { return flip() ? 'red' : 'yellow' };
#     var monoColor = flip(1.0);
#     var stackHeight = function () { return truncGeom(0.7, 1, 8) };
#     var numStacks = truncGeom(0.5, 1, 8);
#     var xpositions = _.range(worldWidth / 2 - tableSize, worldWidth / 2 + tableSize + 20, 20);
#
#     //// Object definitions ////
#
#     var ground = {
#         shape: 'rect',
#         static: true,
#         dims: [100000 * worldWidth, 10],
#         x: worldWidth / 2,
#         y: worldHeight
#     }
#
#     var table = {
#         shape: 'rect',
#         static: false,
#         dims: [tableSize, tableSize],
#         x: worldWidth / 2,
#         y: 390,
#         color: 'blue'
#     }
#
#     var force = function () {
#         var left = flip();
#         return {
#             shape: 'square',
#             static: false,
#             dims: [uniformDraw([15, 16, 17, 18])],
#             x: left ? 100 : worldWidth - 100,
#             y: 310,
#             color: 'green',
#             velocity: left ? [10000, 0] : [-10000, 0]
#         }
#     }
#
#     //// Make stacks ////
#
#     var xposOnTable = function (options) {
#         return uniformDraw(options);
#     }
#
#     var xpos = function (prevBlock) {
#         return prevBlock.x
#     }
#
#     var ypos = function (prevBlock, h) {
#         var prevY = prevBlock.y;
#         var prevH = prevBlock.dims[1];
#         return prevY - (prevH + h)
#     }
#
#     var addBlock = function (prevBlock, isFirst) {
#         var xposition = xposOnTable(xpositions);
#         if (isFirst) {
#             var index = xpositions.indexOf(xposition);
#             xpositions.splice(index, 1);
#         }
#         return {
#             shape: 'rect',
#             color: isFirst || !monoColor ? color() : prevBlock.color,
#             static: false,
#             dims: [dim, dim],
#             x: isFirst ? xposition : xpos(prevBlock),
#             y: ypos(prevBlock, dim)
#         }
#     }
#
#     var stack = function (stackSoFar, h) {
#         var newBlock = addBlock(stackSoFar[stackSoFar.length - 1], false);
#         var theStack = stackSoFar.concat(newBlock);
#         if (stackSoFar.length >= h) {
#             return stackSoFar;
#         } else {
#             return stack(theStack, h);
#         }
#     }
#
#     var makeStacks = function (stacksSoFar, n) {
#         var height = stackHeight();
#         var newStack = stack([addBlock(table, true)], height);
#         var stacks = stacksSoFar.concat([newStack]);
#         if (stacksSoFar.length >= n) {
#             return stacksSoFar;
#         } else {
#             return makeStacks(stacks, n);
#         }
#     }
#
#     var getStackInfo = function (stack) {
#         var color = monoColor ? stack[0].color : 'mixed';
#         var height = stack[0].y - stack[stack.length - 1].y + 2 * dim;
#         return {
#             blocks: stack,
#             color: color,
#             x: stack[0].x,
#             height: height
#         }
#     }
#
#     var realStack = function (stack) {
#         return stack.length >= 2;
#     }
#
#     //// Make world ////
#
#     var rawStacks = makeStacks([], numStacks);
#     var blockList = rawStacks.flat();
#     var rawStacks = filter(realStack, rawStacks);
#     var stacks = map(getStackInfo, rawStacks);
#     var world = {
#         stacks: stacks,
#         blocks: blockList,
#         ground: ground,
#         table: table,
#         force: force()
#     }
#     return world;
# }
#
# ///////////////////
# //// Semantics ////
# ///////////////////
#
# var isRed = function (obj) {
#     return obj.color == 'red';
# }
#
# var isYellow = function (obj) {
#     return obj.color == 'yellow';
# }
#
# var isTall = function (stack) {
#     return stack.height >= 100;
# }
#
# var isShort = function (stack) {
#     return stack.height <= 60;
# }
#
# var isOnLeft = function (obj) {
#     return obj.x <= 270;
# }
#
# var isOnRight = function (obj) {
#     return obj.x >= 330;
# }
#
# var isOnMiddle = function (obj) {
#     return !isOnLeft(obj) && !isOnRight(obj);
# }
#
# var isOnEdge = function (obj) {
#     return obj.x == 200 || obj.x == 400;
# }
#
# var isOnCenter = function (obj) {
#     return obj.x == 300;
# }
#
# var isOnGround = function (obj) {
#     return obj.y > 400;
# }
#
# var isNear = function (obj1) {
#     return function (obj2) {
#         return Math.abs(obj1.x - obj2.x) <= 40;
#     }
# }

# %%
df = pd.read_csv(FILE_STIMULI, index_col="task_id", keep_default_na=False)
df
# Out:
#                                              language_full number location  \
# task_id
# 1        There are four stacks of red blocks, and there...      1
# 2        There are two stacks of yellow blocks, and the...      1
# 3        There are two stacks of red blocks, and there ...      1
# 4        There are yellow blocks on the left side of th...               1
# 5        There are red blocks on the left edge of the t...               1
# ...                                                    ...    ...      ...
# 60       There is at least one tall stack of red blocks...      1        1
# 61       There are at least two tall stacks of yellow b...      1        1
# 62       There is one tall stack of yellow blocks on th...      1        1
# 63       There are two stacks of blocks on the left sid...      1        1
# 64       There are at least five stacks of blocks on th...      1        1
#
#         quant_or_neg vague_adj  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...              ...       ...
# 60                 1         1
# 61                 1         1
# 62                 2         1
# 63                 2         1
# 64                 2         1
#
#                                          language_phrase_1  \
# task_id
# 1                     There are four stacks of red blocks.
# 2                   There are two stacks of yellow blocks.
# 3                      There are two stacks of red blocks.
# 4        There are yellow blocks on the left side of th...
# 5        There are red blocks on the left edge of the t...
# ...                                                    ...
# 60       There is at least one tall stack of red blocks...
# 61       There are at least two tall stacks of yellow b...
# 62       There is one tall stack of yellow blocks on th...
# 63       There are two stacks of blocks on the left sid...
# 64       There are at least five stacks of blocks on th...
#
#                                          language_phrase_2  \
# task_id
# 1                     There is one stack of yellow blocks.
# 2                        There is one stack of red blocks.
# 3                   There are two stacks of yellow blocks.
# 4        There are red blocks on the right edge of the ...
# 5        There are yellow blocks on the right edge of t...
# ...                                                    ...
# 60       There are two stacks of yellow blocks on the r...
# 61       There is at most one tall stack of red blocks ...
# 62              There are no red blocks on the right edge.
# 63       There are three stacks of blocks on the right ...
# 64               No more than half of the stacks are tall.
#
#                                       language_phrase_3  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...                                                 ...
# 60                There are no blocks on the left side.
# 61
# 62
# 63       All of the stacks on the left side are yellow.
# 64                          Most of the stacks are red.
#
#                                         language_phrase_4  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...                                                   ...
# 60
# 61
# 62
# 63       Not all of the stacks on the right side are red.
# 64              Most of the stacks are on the right side.
#
#                                                  code_full  \
# task_id
# 1        condition(filter(isRed, world.stacks).length =...
# 2        condition(filter(isYellow, world.stacks).lengt...
# 3        condition(filter(isRed, world.stacks).length =...
# 4        condition(filter(isOnLeft, filter(isYellow, wo...
# 5        condition(filter(isOnEdge, filter(isOnLeft, fi...
# ...                                                    ...
# 60       condition(filter(isOnMiddle, filter(isTall, fi...
# 61       condition(filter(isOnLeft, filter(isTall, filt...
# 62       condition(filter(isOnEdge, filter(isOnLeft, fi...
# 63       condition(filter(isOnLeft, world.stacks).lengt...
# 64       condition(world.stacks.length >= 5);\nconditio...
#
#                                              code_phrase_1  \
# task_id
# 1        condition(filter(isRed, world.stacks).length =...
# 2        condition(filter(isYellow, world.stacks).lengt...
# 3        condition(filter(isRed, world.stacks).length =...
# 4        condition(filter(isOnLeft, filter(isYellow, wo...
# 5        condition(filter(isOnEdge, filter(isOnLeft, fi...
# ...                                                    ...
# 60       condition(filter(isOnMiddle, filter(isTall, fi...
# 61       condition(filter(isOnLeft, filter(isTall, filt...
# 62       condition(filter(isOnEdge, filter(isOnLeft, fi...
# 63       condition(filter(isOnLeft, world.stacks).lengt...
# 64                    condition(world.stacks.length >= 5);
#
#                                              code_phrase_2  \
# task_id
# 1        condition(filter(isYellow, world.stacks).lengt...
# 2        condition(filter(isRed, world.stacks).length =...
# 3        condition(filter(isYellow, world.stacks).lengt...
# 4        condition(filter(isOnEdge, filter(isOnRight, f...
# 5        condition(filter(isOnEdge, filter(isOnRight, f...
# ...                                                    ...
# 60       condition(filter(isOnRight, filter(isYellow, w...
# 61       condition(filter(isOnRight, filter(isTall, fil...
# 62       condition(filter(isOnEdge, filter(isOnRight, f...
# 63       condition(filter(isOnRight, world.stacks).leng...
# 64       condition(filter(isTall, world.stacks).length ...
#
#                                              code_phrase_3  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...                                                    ...
# 60       condition(filter(isOnLeft, world.blocks).lengt...
# 61
# 62
# 63       condition(all(isYellow, filter(isOnLeft, world...
# 64       condition(filter(isRed, world.stacks).length >...
#
#                                              code_phrase_4 complexity  \
# task_id
# 1                                                                 low
# 2                                                                 low
# 3                                                                 low
# 4                                                                 low
# 5                                                                 low
# ...                                                    ...        ...
# 60                                                               high
# 61                                                               high
# 62                                                               high
# 63       condition(!all(isRed, filter(isOnRight, world....       high
# 64       condition(filter(isOnRight, world.stacks).leng...       high
#
#          example_answer
# task_id
# 1                     2
# 2                     5
# 3                     4
# 4                     3
# 5                     4
# ...                 ...
# 60                    5
# 61                    6
# 62                    6
# 63                    5
# 64                    3
#
# [64 rows x 16 columns]

# %%
n_phrases_langauge = len(list(filter(lambda col_name: "language_phrase_" in col_name, df.columns)))
n_phrases_code = len(list(filter(lambda col_name: "code_phrase_" in col_name, df.columns)))
assert(n_phrases_langauge == n_phrases_code)
N_PHRASES = n_phrases_langauge
print(N_PHRASES)
# Out:
# 4

# %%
TEMPLATE_EXAMPLE_HEADER = """
/**
 * Example:
 * {language_full}
 */
"""

def construct_prompt(df, task_id, global_header, n_prompt_examples: int = None):
    prompt = global_header + "\n"
    
    # hold one out
    df_examples = df.drop(df.loc[[task_id]].index)
    
    if n_prompt_examples:
        df_examples = df_examples.sample(n=n_prompt_examples, random_state=RANDOM_SEED)
    
    for _, row in df_examples.iterrows():
        example_header = TEMPLATE_EXAMPLE_HEADER.format(language_full=row["language_full"])
        prompt += example_header
        
        for i in range(1, N_PHRASES + 1):
            if row[f"language_phrase_{i}"]:
                prompt += "\n"
                prompt += "// " + row[f"language_phrase_{i}"] + "\n"
                prompt += row[f"code_phrase_{i}"] + "\n"
                
    prompt += TEMPLATE_EXAMPLE_HEADER.format(language_full=df.loc[[task_id], "language_full"].item())
        
    return prompt, df_examples.index.tolist()

prompt, task_ids = construct_prompt(df, 1, generative_model_text)

# %%
print(f"{prompt}")

# %%
def query_codex(prompt):
    completion = openai.Completion.create(
        engine=ENGINE,
        prompt=prompt,
        temperature=TEMPERATURE,
        n=N_SAMPLES,
        stop=STOP,
        max_tokens=MAX_TOKENS,
        logprobs=None,
    )
    
    return completion

# %%
def extract_conditions(text):
    start, end = "condition", ";"
    return [start + x + end for x in re.findall(str(re.escape(start)) + "(.*)" + str(re.escape(end)), text)]

def extract_language(text):
    start, end = "// ", "\n"
    return re.findall(str(re.escape(start)) + "(.*)" + str(re.escape(end)), text)

def parse_choice(choice):
    if choice.finish_reason != "stop":
        print(f"WARNING: Completion choice {choice.index} encountered non-terminal finish reason: {choice.finish_reason}")

    data = {
        "choice_index": choice.index,
        "finish_reason": choice.finish_reason,
        "text": choice.text,
    }
    
    for i, (language, code) in enumerate(zip(extract_language(choice.text), extract_conditions(choice.text))):
        data.update({
            f"codex_language_phrase_{i+1}": language,
            f"codex_code_phrase_{i+1}": code,
        })
        
    return data

# %%
def run_experiment(df: pd.DataFrame, experiment_id: str = None, restore_ckpt: bool = False, n_prompt_examples: int = 10):
    experiment_id = experiment_id or datetime.datetime.now().strftime('run-%Y-%m-%d-%H-%M-%S')
    ckpt_dir = os.path.join(DIR_EXPERIMENTS, experiment_id, DIR_CODEX)
    os.makedirs(os.path.join(ckpt_dir, DIR_COMPLETIONS), exist_ok=True)
    os.makedirs(os.path.join(ckpt_dir, DIR_PROMPTS), exist_ok=True)

    completions = []
    # Query OpenAI for completions
    for task_id in tqdm(df.index):
        completion_pkl = os.path.join(ckpt_dir, DIR_COMPLETIONS, f"completion_task_{task_id:03d}.pkl")
        
        # Try loading completion from file
        if restore_ckpt is not None:
            if os.path.exists(completion_pkl):
                with open(completion_pkl, "rb") as f:
                    completions.append(pickle.load(f))
                continue
            else:
                print(f"Completion not found: {completion_pkl}")
            
        prompt_text, prompt_task_ids = construct_prompt(df, task_id, generative_model_text, n_prompt_examples=n_prompt_examples)
        completion = query_codex(prompt_text)
        completions.append(completion)

        with open(completion_pkl, "wb") as f:
            pickle.dump(completion, f)
            
        with open(os.path.join(ckpt_dir, DIR_PROMPTS, f"prompt_task_{task_id:03d}.json"), "w") as f:
            prompt_json = {
                "task_id": task_id,
                "prompt_task_ids": prompt_task_ids,
                "prompt_text": prompt_text,
            }
            json.dump(prompt_json, f)

    # Parse completions data
    results = []
    for task_id, completion in zip(df.index, completions):
        for choice in completion.choices:
            d = {"task_id": task_id}
            d.update(parse_choice(choice))
            results.append(d)

    results_json = {"results": results}
    
    df_results = pd.DataFrame(results_json["results"]).fillna('')
    df_results = df_results.set_index("task_id")
    
    df_results = df.join(df_results)
    df_results.to_csv(os.path.join(DIR_EXPERIMENTS, RUN_ID, DIR_CODEX, "results.csv"))
    
    return df_results

# %%
# df_results = run_experiment(df)

RUN_ID = "run-2023-01-30-12-55-36"
df_results = run_experiment(df, experiment_id=RUN_ID, restore_ckpt=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 64/64 [00:00<00:00, 5994.67it/s]

# %%
df_results
# Out:
#                                              language_full number location  \
# task_id
# 1        There are four stacks of red blocks, and there...      1
# 2        There are two stacks of yellow blocks, and the...      1
# 3        There are two stacks of red blocks, and there ...      1
# 4        There are yellow blocks on the left side of th...               1
# 5        There are red blocks on the left edge of the t...               1
# ...                                                    ...    ...      ...
# 60       There is at least one tall stack of red blocks...      1        1
# 61       There are at least two tall stacks of yellow b...      1        1
# 62       There is one tall stack of yellow blocks on th...      1        1
# 63       There are two stacks of blocks on the left sid...      1        1
# 64       There are at least five stacks of blocks on th...      1        1
#
#         quant_or_neg vague_adj  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...              ...       ...
# 60                 1         1
# 61                 1         1
# 62                 2         1
# 63                 2         1
# 64                 2         1
#
#                                          language_phrase_1  \
# task_id
# 1                     There are four stacks of red blocks.
# 2                   There are two stacks of yellow blocks.
# 3                      There are two stacks of red blocks.
# 4        There are yellow blocks on the left side of th...
# 5        There are red blocks on the left edge of the t...
# ...                                                    ...
# 60       There is at least one tall stack of red blocks...
# 61       There are at least two tall stacks of yellow b...
# 62       There is one tall stack of yellow blocks on th...
# 63       There are two stacks of blocks on the left sid...
# 64       There are at least five stacks of blocks on th...
#
#                                          language_phrase_2  \
# task_id
# 1                     There is one stack of yellow blocks.
# 2                        There is one stack of red blocks.
# 3                   There are two stacks of yellow blocks.
# 4        There are red blocks on the right edge of the ...
# 5        There are yellow blocks on the right edge of t...
# ...                                                    ...
# 60       There are two stacks of yellow blocks on the r...
# 61       There is at most one tall stack of red blocks ...
# 62              There are no red blocks on the right edge.
# 63       There are three stacks of blocks on the right ...
# 64               No more than half of the stacks are tall.
#
#                                       language_phrase_3  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...                                                 ...
# 60                There are no blocks on the left side.
# 61
# 62
# 63       All of the stacks on the left side are yellow.
# 64                          Most of the stacks are red.
#
#                                         language_phrase_4  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...                                                   ...
# 60
# 61
# 62
# 63       Not all of the stacks on the right side are red.
# 64              Most of the stacks are on the right side.
#
#                                                  code_full  ... finish_reason  \
# task_id                                                     ...
# 1        condition(filter(isRed, world.stacks).length =...  ...          stop
# 2        condition(filter(isYellow, world.stacks).lengt...  ...          stop
# 3        condition(filter(isRed, world.stacks).length =...  ...          stop
# 4        condition(filter(isOnLeft, filter(isYellow, wo...  ...          stop
# 5        condition(filter(isOnEdge, filter(isOnLeft, fi...  ...          stop
# ...                                                    ...  ...           ...
# 60       condition(filter(isOnMiddle, filter(isTall, fi...  ...          stop
# 61       condition(filter(isOnLeft, filter(isTall, filt...  ...          stop
# 62       condition(filter(isOnEdge, filter(isOnLeft, fi...  ...          stop
# 63       condition(filter(isOnLeft, world.stacks).lengt...  ...          stop
# 64       condition(world.stacks.length >= 5);\nconditio...  ...          stop
#
#                                                       text  \
# task_id
# 1        \n// There are four stacks of red blocks.\ncon...
# 2        \n// There are two stacks of yellow blocks.\nc...
# 3        \n// There are two stacks of red blocks.\ncond...
# 4        \n// There are yellow blocks on the left side ...
# 5        \n// There are red blocks on the left edge of ...
# ...                                                    ...
# 60       \n// There is at least one tall stack of red b...
# 61       \n// There are at least two tall stacks of yel...
# 62       \n// There is one tall stack of yellow blocks ...
# 63       \n// There are two stacks of blocks on the lef...
# 64       \n// There are at least five stacks of blocks ...
#
#                                    codex_language_phrase_1  \
# task_id
# 1                     There are four stacks of red blocks.
# 2                   There are two stacks of yellow blocks.
# 3                      There are two stacks of red blocks.
# 4        There are yellow blocks on the left side of th...
# 5        There are red blocks on the left edge of the t...
# ...                                                    ...
# 60       There is at least one tall stack of red blocks...
# 61       There are at least two tall stacks of yellow b...
# 62       There is one tall stack of yellow blocks on th...
# 63       There are two stacks of blocks on the left sid...
# 64       There are at least five stacks of blocks on th...
#
#                                        codex_code_phrase_1  \
# task_id
# 1        condition(filter(isRed, world.stacks).length =...
# 2        condition(filter(isYellow, world.stacks).lengt...
# 3        condition(filter(isRed, world.stacks).length =...
# 4        condition(filter(isOnLeft, filter(isYellow, wo...
# 5        condition(filter(isOnLeft, filter(isRed, world...
# ...                                                    ...
# 60       condition(filter(isOnMiddle, filter(isTall, fi...
# 61       condition(filter(isOnLeft, filter(isTall, filt...
# 62       condition(filter(isOnLeft, filter(isTall, filt...
# 63       condition(filter(isOnLeft, world.stacks).lengt...
# 64                    condition(world.stacks.length >= 5);
#
#                                    codex_language_phrase_2  \
# task_id
# 1                     There is one stack of yellow blocks.
# 2                        There is one stack of red blocks.
# 3                   There are two stacks of yellow blocks.
# 4        There are red blocks on the right edge of the ...
# 5        There are yellow blocks on the right edge of t...
# ...                                                    ...
# 60       There are two stacks of yellow blocks on the r...
# 61       There is at most one tall stack of red blocks ...
# 62              There are no red blocks on the right edge.
# 63       There are three stacks of blocks on the right ...
# 64               No more than half of the stacks are tall.
#
#                                        codex_code_phrase_2  \
# task_id
# 1        condition(filter(isYellow, world.stacks).lengt...
# 2        condition(filter(isRed, world.stacks).length =...
# 3        condition(filter(isYellow, world.stacks).lengt...
# 4        condition(filter(isOnRight, filter(isRed, worl...
# 5        condition(filter(isOnRight, filter(isYellow, w...
# ...                                                    ...
# 60       condition(filter(isOnRight, filter(isYellow, w...
# 61       condition(filter(isOnRight, filter(isTall, fil...
# 62       condition(filter(isOnRight, filter(isRed, worl...
# 63       condition(filter(isOnRight, world.stacks).leng...
# 64       condition(filter(isTall, world.stacks).length ...
#
#                                 codex_language_phrase_3  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...                                                 ...
# 60                There are no blocks on the left side.
# 61
# 62
# 63       All of the stacks on the left side are yellow.
# 64                          Most of the stacks are red.
#
#                                        codex_code_phrase_3  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...                                                    ...
# 60       condition(filter(isOnLeft, world.blocks).lengt...
# 61
# 62
# 63       condition(all(isYellow, filter(isOnLeft, world...
# 64       condition(filter(isRed, world.stacks).length >...
#
#                                   codex_language_phrase_4  \
# task_id
# 1
# 2
# 3
# 4
# 5
# ...                                                   ...
# 60
# 61
# 62
# 63       Not all of the stacks on the right side are red.
# 64              Most of the stacks are on the right side.
#
#                                        codex_code_phrase_4
# task_id
# 1
# 2
# 3
# 4
# 5
# ...                                                    ...
# 60
# 61
# 62
# 63       condition(!all(isRed, filter(isOnRight, world....
# 64       condition(filter(isOnRight, world.stacks).leng...
#
# [64 rows x 27 columns]

# %%
for i in range(1, N_PHRASES + 1):
    df_nonempty_language = df_results[df_results[f"language_phrase_{i}"] != '']
    df_nonempty_code = df_results[df_results[f"code_phrase_{i}"] != '']
    
    agreement_language = (df_nonempty_language[f"language_phrase_{i}"] == df_nonempty_language[f"codex_language_phrase_{i}"]).sum() / len(df_nonempty_language)
    agreement_code = (df_nonempty_code[f"code_phrase_{i}"] == df_nonempty_code[f"codex_code_phrase_{i}"]).sum() / len(df_nonempty_code)
    print(f"language_phrase_{i}: {agreement_language:03f}")
    print(f"code_phrase_{i}: {agreement_code:03f}")
# Out:
# language_phrase_1: 0.953125
# code_phrase_1: 0.750000
# language_phrase_2: 0.883333
# code_phrase_2: 0.766667
# language_phrase_3: 1.000000
# code_phrase_3: 0.866667
# language_phrase_4: 1.000000
# code_phrase_4: 0.833333

# %%
from IPython.display import display

with pd.option_context('display.max_colwidth', None):
    for i in range(1, N_PHRASES + 1):
        display(df_results[f"code_phrase_{i}"].compare(df_results[f"codex_code_phrase_{i}"], result_names=('truth', 'codex')))
# Out:
#                                                                                                                                  truth  \
# task_id
# 5                                               condition(filter(isOnEdge, filter(isOnLeft, filter(isRed, world.blocks))).length > 0);
# 8                                                            condition(filter(isYellow, world.blocks).length > world.blocks.length/2);
# 9                                                                                  condition(filter(isRed, world.blocks).length >= 6);
# 10                                 condition(filter(isYellow, world.stacks).length > 2 && filter(isYellow, world.stacks).length <= 5);
# 11                                                          condition(filter(isYellow, world.blocks).length == world.blocks.length/2);
# 13                                                          condition(filter(isYellow, world.blocks).length >= world.blocks.length/2);
# 25                                                                                                condition(world.blocks.length >= 6);
# 31                                       condition(filter(isRed, world.stacks).length > 2 && filter(isRed, world.stacks).length <= 5);
# 48                                             condition(filter(isOnEdge, filter(isOnLeft, filter(isRed, world.stacks))).length == 1);
# 50                            condition(filter(isOnEdge, filter(isOnRight, filter(isTall, filter(isRed, world.stacks)))).length == 1);
# 52                                       condition(filter(isRed, world.stacks).length > 2 && filter(isRed, world.stacks).length <= 5);
# 54                                       condition(filter(isRed, world.stacks).length > 2 && filter(isRed, world.stacks).length <= 5);
# 56       condition(filter(isTall, filter(isRed, world.stacks)).length > 1 && filter(isTall, filter(isRed, world.stacks)).length <= 4);
# 59                                          condition(filter(isOnMiddle, filter(isTall, filter(isYellow, world.stacks))).length == 1);
# 60                                             condition(filter(isOnMiddle, filter(isTall, filter(isRed, world.stacks))).length >= 1);
# 62                          condition(filter(isOnEdge, filter(isOnLeft, filter(isTall, filter(isYellow, world.stacks)))).length == 1);
#
#                                                                                                                                  codex
# task_id
# 5                                                                 condition(filter(isOnLeft, filter(isRed, world.blocks)).length > 0);
# 8                                               condition(filter(isYellow, world.blocks).length > filter(isRed, world.blocks).length);
# 9                                                                                   condition(filter(isRed, world.blocks).length > 5);
# 10                                 condition(filter(isYellow, world.stacks).length > 1 && filter(isYellow, world.stacks).length <= 4);
# 11                                             condition(filter(isYellow, world.blocks).length == filter(isRed, world.blocks).length);
# 13                                                        condition(filter(isYellow, world.blocks).length >= world.blocks.length / 2);
# 25                                                                                               condition(world.blocks.length >= 10);
# 31                                                                                  condition(filter(isRed, world.stacks).length > 2);
# 48                                                               condition(filter(isOnEdge, filter(isRed, world.stacks)).length == 1);
# 50                                               condition(filter(isOnEdge, filter(isTall, filter(isRed, world.stacks))).length == 1);
# 52                                                                                  condition(filter(isRed, world.stacks).length > 1);
# 54                                                                                  condition(filter(isRed, world.stacks).length > 1);
# 56       condition(filter(isTall, filter(isRed, world.stacks)).length > 2 && filter(isTall, filter(isRed, world.stacks)).length <= 5);
# 59                                          condition(filter(isTall, filter(isYellow, filter(isOnMiddle, world.stacks))).length == 1);
# 60                                              condition(filter(isOnMiddle, filter(isTall, filter(isRed, world.stacks))).length > 0);
# 62                                            condition(filter(isOnLeft, filter(isTall, filter(isYellow, world.stacks))).length == 1);
#                                                                                                                                                               truth  \
# task_id
# 4                                                                           condition(filter(isOnEdge, filter(isOnRight, filter(isRed, world.blocks))).length > 0);
# 5                                                                        condition(filter(isOnEdge, filter(isOnRight, filter(isYellow, world.blocks))).length > 0);
# 9                                                               condition(filter(isYellow, world.blocks).length > 1 && filter(isYellow, world.blocks).length <= 4);
# 10                                                                                                              condition(filter(isRed, world.stacks).length <= 4);
# 11                                                                                          condition(filter(isRed, world.blocks).length == world.blocks.length/2);
# 25                                                                                        condition(filter(isYellow, world.blocks).length > world.blocks.length/2);
# 46                                                   condition(filter(isYellow, filter(isOnEdge, world.blocks)).length <= filter(isOnEdge, world.blocks).length/2);
# 48       condition(filter(isNear(filter(isOnEdge, filter(isOnLeft, filter(isRed, world.stacks)))[0]), filter(isTall, filter(isYellow, world.stacks))).length == 2);
# 51                                                            condition(filter(isYellow, world.stacks).length > 0 && all(isShort, filter(isYellow, world.stacks)));
# 52                                                              condition(filter(isOnEdge, world.blocks).length > 1 && filter(isOnEdge, world.blocks).length <= 4);
# 54                                                                                              condition(filter(isTall, filter(isRed, world.stacks)).length == 0);
# 55                                  condition(filter(isShort, filter(isRed, world.stacks)).length > 2 && filter(isShort, filter(isRed, world.stacks)).length <= 5);
# 59                        condition(filter(isNear(filter(isOnMiddle, filter(isTall, filter(isYellow, world.stacks)))[0]), filter(isRed, world.blocks)).length > 0);
# 62                                                                         condition(filter(isOnEdge, filter(isOnRight, filter(isRed, world.stacks))).length == 0);
#
#                                                                                                                                              codex
# task_id
# 4                                                                            condition(filter(isOnRight, filter(isRed, world.blocks)).length > 0);
# 5                                                                         condition(filter(isOnRight, filter(isYellow, world.blocks)).length > 0);
# 9                                              condition(filter(isYellow, world.blocks).length > 1 && filter(isYellow, world.blocks).length <= 5);
# 10                                                   condition(filter(isRed, world.stacks).length > 0 && filter(isRed, world.stacks).length <= 2);
# 11
# 25                                                                    condition(filter(isYellow, world.blocks).length >= world.blocks.length / 2);
# 46                                  condition(filter(isOnEdge, filter(isYellow, world.blocks)).length <= filter(isOnEdge, world.blocks).length/2);
# 48        condition(filter(isNear(filter(isOnEdge, filter(isRed, world.stacks))[0]), filter(isTall, filter(isYellow, world.stacks))).length == 2);
# 51                                                                                        condition(all(isShort, filter(isYellow, world.stacks)));
# 52                                                                                           condition(filter(isOnEdge, world.blocks).length > 1);
# 54                                                                                           condition(all(isShort, filter(isRed, world.stacks)));
# 55                                                                             condition(filter(isShort, filter(isRed, world.stacks)).length > 1);
# 59       condition(filter(isRed, filter(isNear(filter(isTall, filter(isYellow, filter(isOnMiddle, world.stacks)))[0]), world.blocks)).length > 0);
# 62                                                                          condition(filter(isOnRight, filter(isRed, world.blocks)).length == 0);
#                                                                                                                 truth  \
# task_id
# 27       condition(filter(isRed, filter(isOnRight, world.blocks)).length > filter(isOnRight, world.blocks).length/2);
# 57                                                condition(filter(isTall, filter(isRed, world.stacks)).length <= 4);
#
#                                                                                              codex
# task_id
# 27       condition(filter(isOnRight, filter(isRed, world.blocks)).length > world.blocks.length/2);
# 57                              condition(filter(isTall, filter(isRed, world.stacks)).length < 4);
#                                                             truth  \
# task_id
# 39       condition(any(isShort, filter(isYellow, world.stacks)));
#
#                                                                          codex
# task_id
# 39       condition(filter(isTall, filter(isYellow, world.stacks)).length > 0);

# %%
for task_id, row in df_results.iterrows():
    print("---------")
    print(f"task_id {task_id}: {row['language_full']}")
    print()
    
    for i in range(1, N_PHRASES + 1):
        if row[f"language_phrase_{i}"]:
            print(f"Language {i}")
            print(f"TRUTH: {row[f'language_phrase_{i}']}")
            print(f"CODEX: {row[f'codex_language_phrase_{i}']}")
            print()

            print(f"Code {i}")
            print(f"TRUTH: {row[f'code_phrase_{i}']}")
            print(f"CODEX: {row[f'codex_code_phrase_{i}']}")
            print()
# Out:
# ---------
# task_id 1: There are four stacks of red blocks, and there is one stack of yellow blocks.
#
# Language 1
# TRUTH: There are four stacks of red blocks.
# CODEX: There are four stacks of red blocks.
#
# Code 1
# TRUTH: condition(filter(isRed, world.stacks).length == 4);
# CODEX: condition(filter(isRed, world.stacks).length == 4);
#
# Language 2
# TRUTH: There is one stack of yellow blocks.
# CODEX: There is one stack of yellow blocks.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.stacks).length == 1);
# CODEX: condition(filter(isYellow, world.stacks).length == 1);
#
# ---------
# task_id 2: There are two stacks of yellow blocks, and there is one stack of red blocks.
#
# Language 1
# TRUTH: There are two stacks of yellow blocks.
# CODEX: There are two stacks of yellow blocks.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.stacks).length == 2);
# CODEX: condition(filter(isYellow, world.stacks).length == 2);
#
# Language 2
# TRUTH: There is one stack of red blocks.
# CODEX: There is one stack of red blocks.
#
# Code 2
# TRUTH: condition(filter(isRed, world.stacks).length == 1);
# CODEX: condition(filter(isRed, world.stacks).length == 1);
#
# ---------
# task_id 3: There are two stacks of red blocks, and there are two stacks of yellow blocks.
#
# Language 1
# TRUTH: There are two stacks of red blocks.
# CODEX: There are two stacks of red blocks.
#
# Code 1
# TRUTH: condition(filter(isRed, world.stacks).length == 2);
# CODEX: condition(filter(isRed, world.stacks).length == 2);
#
# Language 2
# TRUTH: There are two stacks of yellow blocks.
# CODEX: There are two stacks of yellow blocks.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.stacks).length == 2);
# CODEX: condition(filter(isYellow, world.stacks).length == 2);
#
# ---------
# task_id 4: There are yellow blocks on the left side of the table, and there are red blocks on the right edge of the table.
#
# Language 1
# TRUTH: There are yellow blocks on the left side of the table.
# CODEX: There are yellow blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isYellow, world.blocks)).length > 0);
# CODEX: condition(filter(isOnLeft, filter(isYellow, world.blocks)).length > 0);
#
# Language 2
# TRUTH: There are red blocks on the right edge of the table.
# CODEX: There are red blocks on the right edge of the table.
#
# Code 2
# TRUTH: condition(filter(isOnEdge, filter(isOnRight, filter(isRed, world.blocks))).length > 0);
# CODEX: condition(filter(isOnRight, filter(isRed, world.blocks)).length > 0);
#
# ---------
# task_id 5: There are red blocks on the left edge of the table, and there are yellow blocks on the right edge of the table.
#
# Language 1
# TRUTH: There are red blocks on the left edge of the table.
# CODEX: There are red blocks on the left edge of the table.
#
# Code 1
# TRUTH: condition(filter(isOnEdge, filter(isOnLeft, filter(isRed, world.blocks))).length > 0);
# CODEX: condition(filter(isOnLeft, filter(isRed, world.blocks)).length > 0);
#
# Language 2
# TRUTH: There are yellow blocks on the right edge of the table.
# CODEX: There are yellow blocks on the right edge of the table.
#
# Code 2
# TRUTH: condition(filter(isOnEdge, filter(isOnRight, filter(isYellow, world.blocks))).length > 0);
# CODEX: condition(filter(isOnRight, filter(isYellow, world.blocks)).length > 0);
#
# ---------
# task_id 6: There are yellow blocks on the edges of the table, and there are red blocks on the center of the table.
#
# Language 1
# TRUTH: There are yellow blocks on the edges of the table.
# CODEX: There are yellow blocks on the edges of the table.
#
# Code 1
# TRUTH: condition(filter(isOnEdge, filter(isYellow, world.blocks)).length > 0);
# CODEX: condition(filter(isOnEdge, filter(isYellow, world.blocks)).length > 0);
#
# Language 2
# TRUTH: There are red blocks on the center of the table.
# CODEX: There are red blocks on the center of the table.
#
# Code 2
# TRUTH: condition(filter(isOnCenter, filter(isRed, world.blocks)).length > 0);
# CODEX: condition(filter(isOnCenter, filter(isRed, world.blocks)).length > 0);
#
# ---------
# task_id 7: All of the blocks are red.
#
# Language 1
# TRUTH: All of the blocks are red.
# CODEX: All of the blocks are red.
#
# Code 1
# TRUTH: condition(all(isRed, world.blocks));
# CODEX: condition(all(isRed, world.blocks));
#
# ---------
# task_id 8: Most of the blocks are yellow.
#
# Language 1
# TRUTH: Most of the blocks are yellow.
# CODEX: Most of the blocks are yellow.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.blocks).length > world.blocks.length/2);
# CODEX: condition(filter(isYellow, world.blocks).length > filter(isRed, world.blocks).length);
#
# ---------
# task_id 9: There are many red blocks, and there are a few yellow blocks.
#
# Language 1
# TRUTH: There are many red blocks.
# CODEX: There are many red blocks.
#
# Code 1
# TRUTH: condition(filter(isRed, world.blocks).length >= 6);
# CODEX: condition(filter(isRed, world.blocks).length > 5);
#
# Language 2
# TRUTH: There are a few yellow blocks.
# CODEX: There are a few yellow blocks.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.blocks).length > 1 && filter(isYellow, world.blocks).length <= 4);
# CODEX: condition(filter(isYellow, world.blocks).length > 1 && filter(isYellow, world.blocks).length <= 5);
#
# ---------
# task_id 10: There are several stacks of yellow blocks, and there are few stacks of red blocks.
#
# Language 1
# TRUTH: There are several stacks of yellow blocks.
# CODEX: There are several stacks of yellow blocks.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.stacks).length > 2 && filter(isYellow, world.stacks).length <= 5);
# CODEX: condition(filter(isYellow, world.stacks).length > 1 && filter(isYellow, world.stacks).length <= 4);
#
# Language 2
# TRUTH: There are few stacks of red blocks.
# CODEX: There are few stacks of red blocks.
#
# Code 2
# TRUTH: condition(filter(isRed, world.stacks).length <= 4);
# CODEX: condition(filter(isRed, world.stacks).length > 0 && filter(isRed, world.stacks).length <= 2);
#
# ---------
# task_id 11: Half of the blocks are yellow, and half of the blocks are red.
#
# Language 1
# TRUTH: Half of the blocks are yellow.
# CODEX: Half of the blocks are yellow.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.blocks).length == world.blocks.length/2);
# CODEX: condition(filter(isYellow, world.blocks).length == filter(isRed, world.blocks).length);
#
# Language 2
# TRUTH: Half of the blocks are red.
# CODEX:
#
# Code 2
# TRUTH: condition(filter(isRed, world.blocks).length == world.blocks.length/2);
# CODEX:
#
# ---------
# task_id 12: None of the blocks are red.
#
# Language 1
# TRUTH: None of the blocks are red.
# CODEX: None of the blocks are red.
#
# Code 1
# TRUTH: condition(filter(isRed, world.blocks).length == 0);
# CODEX: condition(filter(isRed, world.blocks).length == 0);
#
# ---------
# task_id 13: No less than half of the blocks are yellow.
#
# Language 1
# TRUTH: No less than half of the blocks are yellow.
# CODEX: No less than half of the blocks are yellow.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.blocks).length >= world.blocks.length/2);
# CODEX: condition(filter(isYellow, world.blocks).length >= world.blocks.length / 2);
#
# ---------
# task_id 14: There are tall stacks of red blocks, and there are short stacks of yellow blocks.
#
# Language 1
# TRUTH: There are tall stacks of red blocks.
# CODEX: There are tall stacks of red blocks.
#
# Code 1
# TRUTH: condition(filter(isTall, filter(isRed, world.stacks)).length > 0);
# CODEX: condition(filter(isTall, filter(isRed, world.stacks)).length > 0);
#
# Language 2
# TRUTH: There are short stacks of yellow blocks.
# CODEX: There are short stacks of yellow blocks.
#
# Code 2
# TRUTH: condition(filter(isShort, filter(isYellow, world.stacks)).length > 0);
# CODEX: condition(filter(isShort, filter(isYellow, world.stacks)).length > 0);
#
# ---------
# task_id 15: There are stacks of yellow blocks, and there are tall stacks of red blocks.
#
# Language 1
# TRUTH: There are stacks of yellow blocks.
# CODEX: There are stacks of yellow blocks.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.stacks).length > 0);
# CODEX: condition(filter(isYellow, world.stacks).length > 0);
#
# Language 2
# TRUTH: There are tall stacks of red blocks.
# CODEX: There are tall stacks of red blocks.
#
# Code 2
# TRUTH: condition(filter(isTall, filter(isRed, world.stacks)).length > 0);
# CODEX: condition(filter(isTall, filter(isRed, world.stacks)).length > 0);
#
# ---------
# task_id 16: There are short stacks of red blocks, and there are short stacks of yellow blocks.
#
# Language 1
# TRUTH: There are short stacks of red blocks.
# CODEX: There are short stacks of red blocks.
#
# Code 1
# TRUTH: condition(filter(isShort, filter(isRed, world.stacks)).length > 0);
# CODEX: condition(filter(isShort, filter(isRed, world.stacks)).length > 0);
#
# Language 2
# TRUTH: There are short stacks of yellow blocks.
# CODEX: There are short stacks of yellow blocks.
#
# Code 2
# TRUTH: condition(filter(isShort, filter(isYellow, world.stacks)).length > 0);
# CODEX: condition(filter(isShort, filter(isYellow, world.stacks)).length > 0);
#
# ---------
# task_id 17: There are four yellow blocks on the left side of the table, and there are seven red blocks on the middle.
#
# Language 1
# TRUTH: There are four yellow blocks on the left side of the table.
# CODEX: There are four yellow blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isYellow, world.blocks)).length == 4);
# CODEX: condition(filter(isOnLeft, filter(isYellow, world.blocks)).length == 4);
#
# Language 2
# TRUTH: There are seven red blocks on the middle.
# CODEX: There are seven red blocks on the middle.
#
# Code 2
# TRUTH: condition(filter(isOnMiddle, filter(isRed, world.blocks)).length == 7);
# CODEX: condition(filter(isOnMiddle, filter(isRed, world.blocks)).length == 7);
#
# ---------
# task_id 18: There is one stack of red blocks on the right side of the table, and there is one stack of yellow blocks on the center.
#
# Language 1
# TRUTH: There is one stack of red blocks on the right side of the table.
# CODEX: There is one stack of red blocks on the right side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnRight, filter(isRed, world.stacks)).length == 1);
# CODEX: condition(filter(isOnRight, filter(isRed, world.stacks)).length == 1);
#
# Language 2
# TRUTH: There is one stack of yellow blocks on the center.
# CODEX: There is one stack of yellow blocks on the center.
#
# Code 2
# TRUTH: condition(filter(isOnCenter, filter(isYellow, world.stacks)).length == 1);
# CODEX: condition(filter(isOnCenter, filter(isYellow, world.stacks)).length == 1);
#
# ---------
# task_id 19: There is one stack of yellow blocks on the left side of the table, and there are two stacks of red blocks on the middle.
#
# Language 1
# TRUTH: There is one stack of yellow blocks on the left side of the table.
# CODEX: There is one stack of yellow blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isYellow, world.stacks)).length == 1);
# CODEX: condition(filter(isOnLeft, filter(isYellow, world.stacks)).length == 1);
#
# Language 2
# TRUTH: There are two stacks of red blocks on the middle.
# CODEX: There are two stacks of red blocks on the middle.
#
# Code 2
# TRUTH: condition(filter(isOnMiddle, filter(isRed, world.stacks)).length == 2);
# CODEX: condition(filter(isOnMiddle, filter(isRed, world.stacks)).length == 2);
#
# ---------
# task_id 20: There are two stacks of red blocks on the left side of the table, and there are two stacks of yellow blocks on the right side.
#
# Language 1
# TRUTH: There are two stacks of red blocks on the left side of the table.
# CODEX: There are two stacks of red blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isRed, world.stacks)).length == 2);
# CODEX: condition(filter(isOnLeft, filter(isRed, world.stacks)).length == 2);
#
# Language 2
# TRUTH: There are two stacks of yellow blocks on the right side.
# CODEX: There are two stacks of yellow blocks on the right side.
#
# Code 2
# TRUTH: condition(filter(isOnRight, filter(isYellow, world.stacks)).length == 2);
# CODEX: condition(filter(isOnRight, filter(isYellow, world.stacks)).length == 2);
#
# ---------
# task_id 21: There is one stack of yellow blocks, and there is one stack of red blocks near the yellow stack.
#
# Language 1
# TRUTH: There is one stack of yellow blocks.
# CODEX: There is one stack of yellow blocks.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.stacks).length == 1);
# CODEX: condition(filter(isYellow, world.stacks).length == 1);
#
# Language 2
# TRUTH: There is one stack of red blocks near the yellow stack.
# CODEX: There is one stack of red blocks near the yellow stack.
#
# Code 2
# TRUTH: condition(filter(isNear(filter(isYellow, world.stacks)[0]), filter(isRed, world.stacks)).length == 1);
# CODEX: condition(filter(isNear(filter(isYellow, world.stacks)[0]), filter(isRed, world.stacks)).length == 1);
#
# ---------
# task_id 22: There are three stacks of red blocks on the left side of the table, and there are two stacks of yellow blocks on the right side.
#
# Language 1
# TRUTH: There are three stacks of red blocks on the left side of the table.
# CODEX: There are three stacks of red blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isRed, world.stacks)).length == 3);
# CODEX: condition(filter(isOnLeft, filter(isRed, world.stacks)).length == 3);
#
# Language 2
# TRUTH: There are two stacks of yellow blocks on the right side.
# CODEX: There are two stacks of yellow blocks on the right side.
#
# Code 2
# TRUTH: condition(filter(isOnRight, filter(isYellow, world.stacks)).length == 2);
# CODEX: condition(filter(isOnRight, filter(isYellow, world.stacks)).length == 2);
#
# ---------
# task_id 23: There are three yellow blocks on the left side of the table, there are six red blocks on the middle, and there are three red blocks on the right side.
#
# Language 1
# TRUTH: There are three yellow blocks on the left side of the table.
# CODEX: There are three yellow blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isYellow, world.blocks)).length == 3);
# CODEX: condition(filter(isOnLeft, filter(isYellow, world.blocks)).length == 3);
#
# Language 2
# TRUTH: There are six red blocks on the middle.
# CODEX: There are six red blocks on the middle.
#
# Code 2
# TRUTH: condition(filter(isOnMiddle, filter(isRed, world.blocks)).length == 6);
# CODEX: condition(filter(isOnMiddle, filter(isRed, world.blocks)).length == 6);
#
# Language 3
# TRUTH: There are three red blocks on the right side.
# CODEX: There are three red blocks on the right side.
#
# Code 3
# TRUTH: condition(filter(isOnRight, filter(isRed, world.blocks)).length == 3);
# CODEX: condition(filter(isOnRight, filter(isRed, world.blocks)).length == 3);
#
# ---------
# task_id 24: There are more red blocks than yellow blocks on the table, and there are more yellow blocks than red blocks on the edges of the table.
#
# Language 1
# TRUTH: There are more red blocks than yellow blocks on the table.
# CODEX: There are more red blocks than yellow blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isRed, world.blocks).length > filter(isYellow, world.blocks).length);
# CODEX: condition(filter(isRed, world.blocks).length > filter(isYellow, world.blocks).length);
#
# Language 2
# TRUTH: There are more yellow blocks than red blocks on the edges of the table.
# CODEX: There are more yellow blocks than red blocks on the edges of the table.
#
# Code 2
# TRUTH: condition(filter(isOnEdge, filter(isYellow, world.blocks)).length > filter(isOnEdge, filter(isRed, world.blocks)).length);
# CODEX: condition(filter(isOnEdge, filter(isYellow, world.blocks)).length > filter(isOnEdge, filter(isRed, world.blocks)).length);
#
# ---------
# task_id 25: There are many blocks on the table. Most of the blocks on the table are yellow. All of the blocks on the middle of the table are red.
#
# Language 1
# TRUTH: There are many blocks on the table.
# CODEX: There are many blocks on the table.
#
# Code 1
# TRUTH: condition(world.blocks.length >= 6);
# CODEX: condition(world.blocks.length >= 10);
#
# Language 2
# TRUTH: Most of the blocks on the table are yellow.
# CODEX: Most of the blocks on the table are yellow.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.blocks).length > world.blocks.length/2);
# CODEX: condition(filter(isYellow, world.blocks).length >= world.blocks.length / 2);
#
# Language 3
# TRUTH: All of the blocks on the middle of the table are red.
# CODEX: All of the blocks on the middle of the table are red.
#
# Code 3
# TRUTH: condition(filter(isOnMiddle, world.blocks).length > 0 && all(isRed, filter(isOnMiddle, world.blocks)));
# CODEX: condition(filter(isOnMiddle, world.blocks).length > 0 && all(isRed, filter(isOnMiddle, world.blocks)));
#
# ---------
# task_id 26: There are more red blocks than yellow blocks on the table. All of the blocks on the edges of the table are yellow.
#
# Language 1
# TRUTH: There are more red blocks than yellow blocks on the table.
# CODEX: There are more red blocks than yellow blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isRed, world.blocks).length > filter(isYellow, world.blocks).length);
# CODEX: condition(filter(isRed, world.blocks).length > filter(isYellow, world.blocks).length);
#
# Language 2
# TRUTH: All of the blocks on the edges of the table are yellow.
# CODEX: All of the blocks on the edges of the table are yellow.
#
# Code 2
# TRUTH: condition(filter(isOnEdge, world.blocks).length > 0 && all(isYellow, filter(isOnEdge, world.blocks)));
# CODEX: condition(filter(isOnEdge, world.blocks).length > 0 && all(isYellow, filter(isOnEdge, world.blocks)));
#
# ---------
# task_id 27: There are many blocks on the table. Not all of the blocks on the left side are yellow. Most of the blocks on the right side are red.
#
# Language 1
# TRUTH: There are many blocks on the table.
# CODEX: There are many blocks on the table.
#
# Code 1
# TRUTH: condition(world.blocks.length >= 6);
# CODEX: condition(world.blocks.length >= 6);
#
# Language 2
# TRUTH: Not all of the blocks on the left side are yellow.
# CODEX: Not all of the blocks on the left side are yellow.
#
# Code 2
# TRUTH: condition(!all(isYellow, filter(isOnLeft, world.blocks)));
# CODEX: condition(!all(isYellow, filter(isOnLeft, world.blocks)));
#
# Language 3
# TRUTH: Most of the blocks on the right side are red.
# CODEX: Most of the blocks on the right side are red.
#
# Code 3
# TRUTH: condition(filter(isRed, filter(isOnRight, world.blocks)).length > filter(isOnRight, world.blocks).length/2);
# CODEX: condition(filter(isOnRight, filter(isRed, world.blocks)).length > world.blocks.length/2);
#
# ---------
# task_id 28: There are red blocks on the edges of the table, and there are no yellow blocks on the egdes of the table.
#
# Language 1
# TRUTH: There are red blocks on the edges of the table.
# CODEX: There are red blocks on the edges of the table.
#
# Code 1
# TRUTH: condition(filter(isOnEdge, filter(isRed, world.blocks)).length > 0);
# CODEX: condition(filter(isOnEdge, filter(isRed, world.blocks)).length > 0);
#
# Language 2
# TRUTH: There are no yellow blocks on the egdes of the table.
# CODEX: There are no yellow blocks on the egdes of the table.
#
# Code 2
# TRUTH: condition(filter(isOnEdge, filter(isYellow, world.blocks)).length == 0);
# CODEX: condition(filter(isOnEdge, filter(isYellow, world.blocks)).length == 0);
#
# ---------
# task_id 29: There are many yellow blocks on the left side of the table, there are no blocks on the middle, and there are no blocks on the right side.
#
# Language 1
# TRUTH: There are many yellow blocks on the left side of the table.
# CODEX: There are many yellow blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isYellow, world.blocks)).length >= 6);
# CODEX: condition(filter(isOnLeft, filter(isYellow, world.blocks)).length >= 6);
#
# Language 2
# TRUTH: There are no blocks on the middle.
# CODEX: There are no blocks on the middle.
#
# Code 2
# TRUTH: condition(filter(isOnMiddle, world.blocks).length == 0);
# CODEX: condition(filter(isOnMiddle, world.blocks).length == 0);
#
# Language 3
# TRUTH: There are no blocks on the right side.
# CODEX: There are no blocks on the right side.
#
# Code 3
# TRUTH: condition(filter(isOnRight, world.blocks).length == 0);
# CODEX: condition(filter(isOnRight, world.blocks).length == 0);
#
# ---------
# task_id 30: There are some stacks of red blocks on the middle of the table, and there are some stacks of yellow blocks on the right side. There are no blocks on the left side.
#
# Language 1
# TRUTH: There are some stacks of red blocks on the middle of the table.
# CODEX: There are some stacks of red blocks on the middle of the table.
#
# Code 1
# TRUTH: condition(filter(isOnMiddle, filter(isRed, world.stacks)).length > 0);
# CODEX: condition(filter(isOnMiddle, filter(isRed, world.stacks)).length > 0);
#
# Language 2
# TRUTH: There are some stacks of yellow blocks on the right side.
# CODEX: There are some stacks of yellow blocks on the right side.
#
# Code 2
# TRUTH: condition(filter(isOnRight, filter(isYellow, world.stacks)).length > 0);
# CODEX: condition(filter(isOnRight, filter(isYellow, world.stacks)).length > 0);
#
# Language 3
# TRUTH: There are no blocks on the left side.
# CODEX: There are no blocks on the left side.
#
# Code 3
# TRUTH: condition(filter(isOnLeft, world.blocks).length == 0);
# CODEX: condition(filter(isOnLeft, world.blocks).length == 0);
#
# ---------
# task_id 31: There are several stacks of red blocks on the table, and there are at most two stacks of yellow blocks on the table.
#
# Language 1
# TRUTH: There are several stacks of red blocks on the table.
# CODEX: There are several stacks of red blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isRed, world.stacks).length > 2 && filter(isRed, world.stacks).length <= 5);
# CODEX: condition(filter(isRed, world.stacks).length > 2);
#
# Language 2
# TRUTH: There are at most two stacks of yellow blocks on the table.
# CODEX: There are at most two stacks of yellow blocks on the table.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.stacks).length <= 2);
# CODEX: condition(filter(isYellow, world.stacks).length <= 2);
#
# ---------
# task_id 32: There are at least seven red blocks on the table, and there are many yellow blocks on the table.
#
# Language 1
# TRUTH: There are at least seven red blocks on the table.
# CODEX: There are at least seven red blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isRed, world.blocks).length >= 7);
# CODEX: condition(filter(isRed, world.blocks).length >= 7);
#
# Language 2
# TRUTH: There are many yellow blocks on the table.
# CODEX: There are many yellow blocks on the table.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.blocks).length >= 6);
# CODEX: condition(filter(isYellow, world.blocks).length >= 6);
#
# ---------
# task_id 33: There are at most six yellow blocks on the table, and there are no more than four red blocks on the table.
#
# Language 1
# TRUTH: There are at most six yellow blocks on the table.
# CODEX: There are at most six yellow blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.blocks).length <= 6);
# CODEX: condition(filter(isYellow, world.blocks).length <= 6);
#
# Language 2
# TRUTH: There are no more than four red blocks on the table.
# CODEX: There are no more than four red blocks on the table.
#
# Code 2
# TRUTH: condition(filter(isRed, world.blocks).length <= 4);
# CODEX: condition(filter(isRed, world.blocks).length <= 4);
#
# ---------
# task_id 34: There are eight red blocks on the table, and there are no yellow blocks on the table.
#
# Language 1
# TRUTH: There are eight red blocks on the table.
# CODEX: There are eight red blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isRed, world.blocks).length == 8);
# CODEX: condition(filter(isRed, world.blocks).length == 8);
#
# Language 2
# TRUTH: There are no yellow blocks on the table.
# CODEX: There are no yellow blocks on the table.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.blocks).length == 0);
# CODEX: condition(filter(isYellow, world.blocks).length == 0);
#
# ---------
# task_id 35: There are two tall stacks of yellow blocks, and there are two short stacks of red blocks.
#
# Language 1
# TRUTH: There are two tall stacks of yellow blocks.
# CODEX: There are two tall stacks of yellow blocks.
#
# Code 1
# TRUTH: condition(filter(isTall, filter(isYellow, world.stacks)).length == 2);
# CODEX: condition(filter(isTall, filter(isYellow, world.stacks)).length == 2);
#
# Language 2
# TRUTH: There are two short stacks of red blocks.
# CODEX: There are two short stacks of red blocks.
#
# Code 2
# TRUTH: condition(filter(isShort, filter(isRed, world.stacks)).length == 2);
# CODEX: condition(filter(isShort, filter(isRed, world.stacks)).length == 2);
#
# ---------
# task_id 36: There is one tall stack of red blocks, and there are two short stacks of yellow blocks.
#
# Language 1
# TRUTH: There is one tall stack of red blocks.
# CODEX: There is one tall stack of red blocks.
#
# Code 1
# TRUTH: condition(filter(isTall, filter(isRed, world.stacks)).length == 1);
# CODEX: condition(filter(isTall, filter(isRed, world.stacks)).length == 1);
#
# Language 2
# TRUTH: There are two short stacks of yellow blocks.
# CODEX: There are two short stacks of yellow blocks.
#
# Code 2
# TRUTH: condition(filter(isShort, filter(isYellow, world.stacks)).length == 2);
# CODEX: condition(filter(isShort, filter(isYellow, world.stacks)).length == 2);
#
# ---------
# task_id 37: There are two tall stacks of yellow blocks, and there are three short stacks of red blocks.
#
# Language 1
# TRUTH: There are two tall stacks of yellow blocks.
# CODEX: There are two tall stacks of yellow blocks.
#
# Code 1
# TRUTH: condition(filter(isTall, filter(isYellow, world.stacks)).length == 2);
# CODEX: condition(filter(isTall, filter(isYellow, world.stacks)).length == 2);
#
# Language 2
# TRUTH: There are three short stacks of red blocks.
# CODEX: There are three short stacks of red blocks.
#
# Code 2
# TRUTH: condition(filter(isShort, filter(isRed, world.stacks)).length == 3);
# CODEX: condition(filter(isShort, filter(isRed, world.stacks)).length == 3);
#
# ---------
# task_id 38: There are stacks of yellow blocks, and there are stacks of red blocks. All of the yellow stacks are tall, and all of the red stacks are short.
#
# Language 1
# TRUTH: There are stacks of yellow blocks.
# CODEX: There are stacks of yellow blocks.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.stacks).length > 0);
# CODEX: condition(filter(isYellow, world.stacks).length > 0);
#
# Language 2
# TRUTH: There are stacks of red blocks.
# CODEX: There are stacks of red blocks.
#
# Code 2
# TRUTH: condition(filter(isRed, world.stacks).length > 0);
# CODEX: condition(filter(isRed, world.stacks).length > 0);
#
# Language 3
# TRUTH: All of the yellow stacks are tall.
# CODEX: All of the yellow stacks are tall.
#
# Code 3
# TRUTH: condition(all(isTall, filter(isYellow, world.stacks)));
# CODEX: condition(all(isTall, filter(isYellow, world.stacks)));
#
# Language 4
# TRUTH: All of the red stacks are short.
# CODEX: All of the red stacks are short.
#
# Code 4
# TRUTH: condition(all(isShort, filter(isRed, world.stacks)));
# CODEX: condition(all(isShort, filter(isRed, world.stacks)));
#
# ---------
# task_id 39: There are stacks of red blocks, and there are stacks of yellow blocks. All of the red stacks are tall, and some of the yellow stacks are tall.
#
# Language 1
# TRUTH: There are stacks of red blocks.
# CODEX: There are stacks of red blocks.
#
# Code 1
# TRUTH: condition(filter(isRed, world.stacks).length > 0);
# CODEX: condition(filter(isRed, world.stacks).length > 0);
#
# Language 2
# TRUTH: There are stacks of yellow blocks.
# CODEX: There are stacks of yellow blocks.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.stacks).length > 0);
# CODEX: condition(filter(isYellow, world.stacks).length > 0);
#
# Language 3
# TRUTH: All of the red stacks are tall.
# CODEX: All of the red stacks are tall.
#
# Code 3
# TRUTH: condition(all(isTall, filter(isRed, world.stacks)));
# CODEX: condition(all(isTall, filter(isRed, world.stacks)));
#
# Language 4
# TRUTH: Some of the yellow stacks are tall.
# CODEX: Some of the yellow stacks are tall.
#
# Code 4
# TRUTH: condition(any(isShort, filter(isYellow, world.stacks)));
# CODEX: condition(filter(isTall, filter(isYellow, world.stacks)).length > 0);
#
# ---------
# task_id 40: There are some short stacks of yellow blocks, and there are some tall stacks of red blocks.
#
# Language 1
# TRUTH: There are some short stacks of yellow blocks.
# CODEX: There are some short stacks of yellow blocks.
#
# Code 1
# TRUTH: condition(filter(isShort, filter(isYellow, world.stacks)).length > 0);
# CODEX: condition(filter(isShort, filter(isYellow, world.stacks)).length > 0);
#
# Language 2
# TRUTH: There are some tall stacks of red blocks.
# CODEX: There are some tall stacks of red blocks.
#
# Code 2
# TRUTH: condition(filter(isTall, filter(isRed, world.stacks)).length > 0);
# CODEX: condition(filter(isTall, filter(isRed, world.stacks)).length > 0);
#
# ---------
# task_id 41: There are many red blocks on the left side of the table, and there is at most one stack of yellow blocks on the right side.
#
# Language 1
# TRUTH: There are many red blocks on the left side of the table.
# CODEX: There are many red blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isRed, world.blocks)).length >= 6);
# CODEX: condition(filter(isOnLeft, filter(isRed, world.blocks)).length >= 6);
#
# Language 2
# TRUTH: There is at most one stack of yellow blocks on the right side.
# CODEX: There is at most one stack of yellow blocks on the right side.
#
# Code 2
# TRUTH: condition(filter(isOnRight, filter(isYellow, world.stacks)).length <= 1);
# CODEX: condition(filter(isOnRight, filter(isYellow, world.stacks)).length <= 1);
#
# ---------
# task_id 42: There is one stack of yellow blocks on the left side of the table, and there are some red blocks on the middle.
#
# Language 1
# TRUTH: There is one stack of yellow blocks on the left side of the table.
# CODEX: There is one stack of yellow blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isYellow, world.stacks)).length == 1);
# CODEX: condition(filter(isOnLeft, filter(isYellow, world.stacks)).length == 1);
#
# Language 2
# TRUTH: There are some red blocks on the middle.
# CODEX: There are some red blocks on the middle.
#
# Code 2
# TRUTH: condition(filter(isOnMiddle, filter(isRed, world.blocks)).length > 0);
# CODEX: condition(filter(isOnMiddle, filter(isRed, world.blocks)).length > 0);
#
# ---------
# task_id 43: There are many red blocks on the left side of the table, and there are two stacks of yellow blocks on the left side.
#
# Language 1
# TRUTH: There are many red blocks on the left side of the table.
# CODEX: There are many red blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isRed, world.blocks)).length >= 6);
# CODEX: condition(filter(isOnLeft, filter(isRed, world.blocks)).length >= 6);
#
# Language 2
# TRUTH: There are two stacks of yellow blocks on the left side.
# CODEX: There are two stacks of yellow blocks on the left side.
#
# Code 2
# TRUTH: condition(filter(isOnLeft, filter(isYellow, world.stacks)).length == 2);
# CODEX: condition(filter(isOnLeft, filter(isYellow, world.stacks)).length == 2);
#
# ---------
# task_id 44: There are three yellow blocks on the right side of the table, and there are many red blocks on the right side.
#
# Language 1
# TRUTH: There are three yellow blocks on the right side of the table.
# CODEX: There are three yellow blocks on the right side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnRight, filter(isYellow, world.blocks)).length == 3);
# CODEX: condition(filter(isOnRight, filter(isYellow, world.blocks)).length == 3);
#
# Language 2
# TRUTH: There are many red blocks on the right side.
# CODEX: There are many red blocks on the right side.
#
# Code 2
# TRUTH: condition(filter(isOnRight, filter(isRed, world.blocks)).length >= 6);
# CODEX: condition(filter(isOnRight, filter(isRed, world.blocks)).length >= 6);
#
# ---------
# task_id 45: There are four red blocks on the left side of the table, and there are no less than five yellow blocks on the right side.
#
# Language 1
# TRUTH: There are four red blocks on the left side of the table.
# CODEX: There are four red blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isRed, world.blocks)).length == 4);
# CODEX: condition(filter(isOnLeft, filter(isRed, world.blocks)).length == 4);
#
# Language 2
# TRUTH: There are no less than five yellow blocks on the right side.
# CODEX: There are no less than five yellow blocks on the right side.
#
# Code 2
# TRUTH: condition(filter(isOnRight, filter(isYellow, world.blocks)).length >= 5);
# CODEX: condition(filter(isOnRight, filter(isYellow, world.blocks)).length >= 5);
#
# ---------
# task_id 46: There are eight red blocks on the middle of the table, and no more than half of the blocks on the edges of the table are yellow.
#
# Language 1
# TRUTH: There are eight red blocks on the middle of the table.
# CODEX: There are eight red blocks on the middle of the table.
#
# Code 1
# TRUTH: condition(filter(isOnMiddle, filter(isRed, world.blocks)).length == 8);
# CODEX: condition(filter(isOnMiddle, filter(isRed, world.blocks)).length == 8);
#
# Language 2
# TRUTH: No more than half of the blocks on the edges of the table are yellow.
# CODEX: No more than half of the blocks on the edges of the table are yellow.
#
# Code 2
# TRUTH: condition(filter(isYellow, filter(isOnEdge, world.blocks)).length <= filter(isOnEdge, world.blocks).length/2);
# CODEX: condition(filter(isOnEdge, filter(isYellow, world.blocks)).length <= filter(isOnEdge, world.blocks).length/2);
#
# ---------
# task_id 47: There is one stack of yellow blocks on the middle of the table, and there are two short stacks of red blocks near the yellow stack.
#
# Language 1
# TRUTH: There is one stack of yellow blocks on the middle of the table.
# CODEX: There is one stack of yellow blocks on the middle of the table.
#
# Code 1
# TRUTH: condition(filter(isOnMiddle, filter(isYellow, world.stacks)).length == 1);
# CODEX: condition(filter(isOnMiddle, filter(isYellow, world.stacks)).length == 1);
#
# Language 2
# TRUTH: There are two short stacks of red blocks near the yellow stack.
# CODEX: There are two short stacks of red blocks near the yellow stack.
#
# Code 2
# TRUTH: condition(filter(isNear(filter(isOnMiddle, filter(isYellow, world.stacks))[0]), filter(isShort, filter(isRed, world.stacks))).length == 2);
# CODEX: condition(filter(isNear(filter(isOnMiddle, filter(isYellow, world.stacks))[0]), filter(isShort, filter(isRed, world.stacks))).length == 2);
#
# ---------
# task_id 48: There is one stack of red blocks on the left edge of the table, and there are two tall stacks of yellow blocks near the red stack.
#
# Language 1
# TRUTH: There is one stack of red blocks on the left edge of the table.
# CODEX: There is one stack of red blocks on the left edge of the table.
#
# Code 1
# TRUTH: condition(filter(isOnEdge, filter(isOnLeft, filter(isRed, world.stacks))).length == 1);
# CODEX: condition(filter(isOnEdge, filter(isRed, world.stacks)).length == 1);
#
# Language 2
# TRUTH: There are two tall stacks of yellow blocks near the red stack.
# CODEX: There are two tall stacks of yellow blocks near the red stack.
#
# Code 2
# TRUTH: condition(filter(isNear(filter(isOnEdge, filter(isOnLeft, filter(isRed, world.stacks)))[0]), filter(isTall, filter(isYellow, world.stacks))).length == 2);
# CODEX: condition(filter(isNear(filter(isOnEdge, filter(isRed, world.stacks))[0]), filter(isTall, filter(isYellow, world.stacks))).length == 2);
#
# ---------
# task_id 49: There is one stack of yellow blocks on the center of the table, and there is one tall stack of red blocks near the yellow stack.
#
# Language 1
# TRUTH: There is one stack of yellow blocks on the center of the table.
# CODEX: There is one stack of yellow blocks on the center of the table.
#
# Code 1
# TRUTH: condition(filter(isOnCenter, filter(isYellow, world.stacks)).length == 1);
# CODEX: condition(filter(isOnCenter, filter(isYellow, world.stacks)).length == 1);
#
# Language 2
# TRUTH: There is one tall stack of red blocks near the yellow stack.
# CODEX: There is one tall stack of red blocks near the yellow stack.
#
# Code 2
# TRUTH: condition(filter(isNear(filter(isOnCenter, filter(isYellow, world.stacks))[0]), filter(isTall, filter(isRed, world.stacks))).length == 1);
# CODEX: condition(filter(isNear(filter(isOnCenter, filter(isYellow, world.stacks))[0]), filter(isTall, filter(isRed, world.stacks))).length == 1);
#
# ---------
# task_id 50: There is one tall stack of red blocks on the right edge of the table, and there are two yellow blocks on the middle of the table.
#
# Language 1
# TRUTH: There is one tall stack of red blocks on the right edge of the table.
# CODEX: There is one tall stack of red blocks on the right edge of the table.
#
# Code 1
# TRUTH: condition(filter(isOnEdge, filter(isOnRight, filter(isTall, filter(isRed, world.stacks)))).length == 1);
# CODEX: condition(filter(isOnEdge, filter(isTall, filter(isRed, world.stacks))).length == 1);
#
# Language 2
# TRUTH: There are two yellow blocks on the middle of the table.
# CODEX: There are two yellow blocks on the middle of the table.
#
# Code 2
# TRUTH: condition(filter(isOnMiddle, filter(isYellow, world.blocks)).length == 2);
# CODEX: condition(filter(isOnMiddle, filter(isYellow, world.blocks)).length == 2);
#
# ---------
# task_id 51: There are less stacks of yellow blocks than stacks of red blocks on the table. All of the yellow stacks are short.
#
# Language 1
# TRUTH: There are less stacks of yellow blocks than stacks of red blocks on the table.
# CODEX: There are less stacks of yellow blocks than stacks of red blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.stacks).length < filter(isRed, world.stacks).length);
# CODEX: condition(filter(isYellow, world.stacks).length < filter(isRed, world.stacks).length);
#
# Language 2
# TRUTH: All of the yellow stacks are short.
# CODEX: All of the yellow stacks are short.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.stacks).length > 0 && all(isShort, filter(isYellow, world.stacks)));
# CODEX: condition(all(isShort, filter(isYellow, world.stacks)));
#
# ---------
# task_id 52: There are several stacks of red blocks on the table, and there are a few blocks on the edges of the table. Less than half of the blocks on the edges are yellow.
#
# Language 1
# TRUTH: There are several stacks of red blocks on the table.
# CODEX: There are several stacks of red blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isRed, world.stacks).length > 2 && filter(isRed, world.stacks).length <= 5);
# CODEX: condition(filter(isRed, world.stacks).length > 1);
#
# Language 2
# TRUTH: There are a few blocks on the edges of the table.
# CODEX: There are a few blocks on the edges of the table.
#
# Code 2
# TRUTH: condition(filter(isOnEdge, world.blocks).length > 1 && filter(isOnEdge, world.blocks).length <= 4);
# CODEX: condition(filter(isOnEdge, world.blocks).length > 1);
#
# Language 3
# TRUTH: Less than half of the blocks on the edges are yellow.
# CODEX: Less than half of the blocks on the edges are yellow.
#
# Code 3
# TRUTH: condition(filter(isYellow, filter(isOnEdge, world.blocks)).length < filter(isOnEdge, world.blocks).length/2);
# CODEX: condition(filter(isYellow, filter(isOnEdge, world.blocks)).length < filter(isOnEdge, world.blocks).length/2);
#
# ---------
# task_id 53: There are more stacks of yellow blocks than stacks of red blocks on the table. None of the yellow stacks are tall. Most of the red stacks are tall.
#
# Language 1
# TRUTH: There are more stacks of yellow blocks than stacks of red blocks on the table.
# CODEX: There are more stacks of yellow blocks than stacks of red blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isYellow, world.stacks).length > filter(isRed, world.stacks).length);
# CODEX: condition(filter(isYellow, world.stacks).length > filter(isRed, world.stacks).length);
#
# Language 2
# TRUTH: None of the yellow stacks are tall.
# CODEX: None of the yellow stacks are tall.
#
# Code 2
# TRUTH: condition(filter(isTall, filter(isYellow, world.stacks)).length == 0);
# CODEX: condition(filter(isTall, filter(isYellow, world.stacks)).length == 0);
#
# Language 3
# TRUTH: Most of the red stacks are tall.
# CODEX: Most of the red stacks are tall.
#
# Code 3
# TRUTH: condition(filter(isTall, filter(isRed, world.stacks)).length > filter(isRed, world.stacks).length/2);
# CODEX: condition(filter(isTall, filter(isRed, world.stacks)).length > filter(isRed, world.stacks).length/2);
#
# ---------
# task_id 54: There are several stacks of red blocks on the table, and none of the red stacks are tall. There are a few yellow blocks, and all of the yellow blocks are on the egdes of the table.
#
# Language 1
# TRUTH: There are several stacks of red blocks on the table.
# CODEX: There are several stacks of red blocks on the table.
#
# Code 1
# TRUTH: condition(filter(isRed, world.stacks).length > 2 && filter(isRed, world.stacks).length <= 5);
# CODEX: condition(filter(isRed, world.stacks).length > 1);
#
# Language 2
# TRUTH: None of the red stacks are tall.
# CODEX: None of the red stacks are tall.
#
# Code 2
# TRUTH: condition(filter(isTall, filter(isRed, world.stacks)).length == 0);
# CODEX: condition(all(isShort, filter(isRed, world.stacks)));
#
# Language 3
# TRUTH: There are a few yellow blocks.
# CODEX: There are a few yellow blocks.
#
# Code 3
# TRUTH: condition(filter(isYellow, world.blocks).length > 1 && filter(isYellow, world.blocks).length <= 4);
# CODEX: condition(filter(isYellow, world.blocks).length > 1 && filter(isYellow, world.blocks).length <= 4);
#
# Language 4
# TRUTH: All of the yellow blocks are on the egdes of the table.
# CODEX: All of the yellow blocks are on the egdes of the table.
#
# Code 4
# TRUTH: condition(all(isOnEdge, filter(isYellow, world.blocks)));
# CODEX: condition(all(isOnEdge, filter(isYellow, world.blocks)));
#
# ---------
# task_id 55: There are two tall stacks of yellow blocks, and there are several short stacks of red blocks.
#
# Language 1
# TRUTH: There are two tall stacks of yellow blocks.
# CODEX: There are two tall stacks of yellow blocks.
#
# Code 1
# TRUTH: condition(filter(isTall, filter(isYellow, world.stacks)).length == 2);
# CODEX: condition(filter(isTall, filter(isYellow, world.stacks)).length == 2);
#
# Language 2
# TRUTH: There are several short stacks of red blocks.
# CODEX: There are several short stacks of red blocks.
#
# Code 2
# TRUTH: condition(filter(isShort, filter(isRed, world.stacks)).length > 2 && filter(isShort, filter(isRed, world.stacks)).length <= 5);
# CODEX: condition(filter(isShort, filter(isRed, world.stacks)).length > 1);
#
# ---------
# task_id 56: There are a few tall stacks of red blocks, and there are four stacks of yellow blocks.
#
# Language 1
# TRUTH: There are a few tall stacks of red blocks.
# CODEX: There are a few tall stacks of red blocks.
#
# Code 1
# TRUTH: condition(filter(isTall, filter(isRed, world.stacks)).length > 1 && filter(isTall, filter(isRed, world.stacks)).length <= 4);
# CODEX: condition(filter(isTall, filter(isRed, world.stacks)).length > 2 && filter(isTall, filter(isRed, world.stacks)).length <= 5);
#
# Language 2
# TRUTH: There are four stacks of yellow blocks.
# CODEX: There are four stacks of yellow blocks.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.stacks).length == 4);
# CODEX: condition(filter(isYellow, world.stacks).length == 4);
#
# ---------
# task_id 57: There are many stacks of blocks on the table. There are no tall yellow stacks, and there are less than four tall red stacks.
#
# Language 1
# TRUTH: There are many stacks of blocks on the table.
# CODEX: There are many stacks of blocks on the table.
#
# Code 1
# TRUTH: condition(world.stacks.length >= 6);
# CODEX: condition(world.stacks.length >= 6);
#
# Language 2
# TRUTH: There are no tall yellow stacks.
# CODEX: There are no tall yellow stacks.
#
# Code 2
# TRUTH: condition(filter(isTall, filter(isYellow, world.stacks)).length == 0);
# CODEX: condition(filter(isTall, filter(isYellow, world.stacks)).length == 0);
#
# Language 3
# TRUTH: There are less than four tall red stacks.
# CODEX: There are less than four tall red stacks.
#
# Code 3
# TRUTH: condition(filter(isTall, filter(isRed, world.stacks)).length <= 4);
# CODEX: condition(filter(isTall, filter(isRed, world.stacks)).length < 4);
#
# ---------
# task_id 58: There are three stacks of red blocks, and there are two stacks of yellow blocks. There are no tall red stacks, and there are no short yellow stacks.
#
# Language 1
# TRUTH: There are three stacks of red blocks.
# CODEX: There are three stacks of red blocks.
#
# Code 1
# TRUTH: condition(filter(isRed, world.stacks).length == 3);
# CODEX: condition(filter(isRed, world.stacks).length == 3);
#
# Language 2
# TRUTH: There are two stacks of yellow blocks.
# CODEX: There are two stacks of yellow blocks.
#
# Code 2
# TRUTH: condition(filter(isYellow, world.stacks).length == 2);
# CODEX: condition(filter(isYellow, world.stacks).length == 2);
#
# Language 3
# TRUTH: There are no tall red stacks.
# CODEX: There are no tall red stacks.
#
# Code 3
# TRUTH: condition(filter(isTall, filter(isRed, world.stacks)).length == 0);
# CODEX: condition(filter(isTall, filter(isRed, world.stacks)).length == 0);
#
# Language 4
# TRUTH: There are no short yellow stacks.
# CODEX: There are no short yellow stacks.
#
# Code 4
# TRUTH: condition(filter(isShort, filter(isYellow, world.stacks)).length == 0);
# CODEX: condition(filter(isShort, filter(isYellow, world.stacks)).length == 0);
#
# ---------
# task_id 59: There is one tall stack of yellow blocks on the middle of the table, and there are some red blocks near the yellow stack.
#
# Language 1
# TRUTH: There is one tall stack of yellow blocks on the middle of the table.
# CODEX: There is one tall stack of yellow blocks on the middle of the table.
#
# Code 1
# TRUTH: condition(filter(isOnMiddle, filter(isTall, filter(isYellow, world.stacks))).length == 1);
# CODEX: condition(filter(isTall, filter(isYellow, filter(isOnMiddle, world.stacks))).length == 1);
#
# Language 2
# TRUTH: There are some red blocks near the yellow stack.
# CODEX: There are some red blocks near the yellow stack.
#
# Code 2
# TRUTH: condition(filter(isNear(filter(isOnMiddle, filter(isTall, filter(isYellow, world.stacks)))[0]), filter(isRed, world.blocks)).length > 0);
# CODEX: condition(filter(isRed, filter(isNear(filter(isTall, filter(isYellow, filter(isOnMiddle, world.stacks)))[0]), world.blocks)).length > 0);
#
# ---------
# task_id 60: There is at least one tall stack of red blocks on the middle of the table, and there are two stacks of yellow blocks on the right side. There are no blocks on the left side.
#
# Language 1
# TRUTH: There is at least one tall stack of red blocks on the middle of the table.
# CODEX: There is at least one tall stack of red blocks on the middle of the table.
#
# Code 1
# TRUTH: condition(filter(isOnMiddle, filter(isTall, filter(isRed, world.stacks))).length >= 1);
# CODEX: condition(filter(isOnMiddle, filter(isTall, filter(isRed, world.stacks))).length > 0);
#
# Language 2
# TRUTH: There are two stacks of yellow blocks on the right side.
# CODEX: There are two stacks of yellow blocks on the right side.
#
# Code 2
# TRUTH: condition(filter(isOnRight, filter(isYellow, world.stacks)).length == 2);
# CODEX: condition(filter(isOnRight, filter(isYellow, world.stacks)).length == 2);
#
# Language 3
# TRUTH: There are no blocks on the left side.
# CODEX: There are no blocks on the left side.
#
# Code 3
# TRUTH: condition(filter(isOnLeft, world.blocks).length == 0);
# CODEX: condition(filter(isOnLeft, world.blocks).length == 0);
#
# ---------
# task_id 61: There are at least two tall stacks of yellow blocks on the left side of the table, and there is at most one tall stack of red blocks on the right side.
#
# Language 1
# TRUTH: There are at least two tall stacks of yellow blocks on the left side of the table.
# CODEX: There are at least two tall stacks of yellow blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, filter(isTall, filter(isYellow, world.stacks))).length >= 2);
# CODEX: condition(filter(isOnLeft, filter(isTall, filter(isYellow, world.stacks))).length >= 2);
#
# Language 2
# TRUTH: There is at most one tall stack of red blocks on the right side.
# CODEX: There is at most one tall stack of red blocks on the right side.
#
# Code 2
# TRUTH: condition(filter(isOnRight, filter(isTall, filter(isRed, world.stacks))).length <= 1);
# CODEX: condition(filter(isOnRight, filter(isTall, filter(isRed, world.stacks))).length <= 1);
#
# ---------
# task_id 62: There is one tall stack of yellow blocks on the left edge of the table, and there are no red blocks on the right edge.
#
# Language 1
# TRUTH: There is one tall stack of yellow blocks on the left edge of the table.
# CODEX: There is one tall stack of yellow blocks on the left edge of the table.
#
# Code 1
# TRUTH: condition(filter(isOnEdge, filter(isOnLeft, filter(isTall, filter(isYellow, world.stacks)))).length == 1);
# CODEX: condition(filter(isOnLeft, filter(isTall, filter(isYellow, world.stacks))).length == 1);
#
# Language 2
# TRUTH: There are no red blocks on the right edge.
# CODEX: There are no red blocks on the right edge.
#
# Code 2
# TRUTH: condition(filter(isOnEdge, filter(isOnRight, filter(isRed, world.stacks))).length == 0);
# CODEX: condition(filter(isOnRight, filter(isRed, world.blocks)).length == 0);
#
# ---------
# task_id 63: There are two stacks of blocks on the left side of the table, and there are three stacks of blocks on the right side. All of the stacks on the left side are yellow, and not all of the stacks on the right side are red.
#
# Language 1
# TRUTH: There are two stacks of blocks on the left side of the table.
# CODEX: There are two stacks of blocks on the left side of the table.
#
# Code 1
# TRUTH: condition(filter(isOnLeft, world.stacks).length == 2);
# CODEX: condition(filter(isOnLeft, world.stacks).length == 2);
#
# Language 2
# TRUTH: There are three stacks of blocks on the right side.
# CODEX: There are three stacks of blocks on the right side.
#
# Code 2
# TRUTH: condition(filter(isOnRight, world.stacks).length == 3);
# CODEX: condition(filter(isOnRight, world.stacks).length == 3);
#
# Language 3
# TRUTH: All of the stacks on the left side are yellow.
# CODEX: All of the stacks on the left side are yellow.
#
# Code 3
# TRUTH: condition(all(isYellow, filter(isOnLeft, world.stacks)));
# CODEX: condition(all(isYellow, filter(isOnLeft, world.stacks)));
#
# Language 4
# TRUTH: Not all of the stacks on the right side are red.
# CODEX: Not all of the stacks on the right side are red.
#
# Code 4
# TRUTH: condition(!all(isRed, filter(isOnRight, world.stacks)));
# CODEX: condition(!all(isRed, filter(isOnRight, world.stacks)));
#
# ---------
# task_id 64: There are at least five stacks of blocks on the table. No more than half of the stacks are tall. Most of the stacks are red, and most of the stacks are on the right side.
#
# Language 1
# TRUTH: There are at least five stacks of blocks on the table.
# CODEX: There are at least five stacks of blocks on the table.
#
# Code 1
# TRUTH: condition(world.stacks.length >= 5);
# CODEX: condition(world.stacks.length >= 5);
#
# Language 2
# TRUTH: No more than half of the stacks are tall.
# CODEX: No more than half of the stacks are tall.
#
# Code 2
# TRUTH: condition(filter(isTall, world.stacks).length <= world.stacks.length/2);
# CODEX: condition(filter(isTall, world.stacks).length <= world.stacks.length/2);
#
# Language 3
# TRUTH: Most of the stacks are red.
# CODEX: Most of the stacks are red.
#
# Code 3
# TRUTH: condition(filter(isRed, world.stacks).length > world.stacks.length/2);
# CODEX: condition(filter(isRed, world.stacks).length > world.stacks.length/2);
#
# Language 4
# TRUTH: Most of the stacks are on the right side.
# CODEX: Most of the stacks are on the right side.
#
# Code 4
# TRUTH: condition(filter(isOnRight, world.stacks).length > world.stacks.length/2);
# CODEX: condition(filter(isOnRight, world.stacks).length > world.stacks.length/2);
